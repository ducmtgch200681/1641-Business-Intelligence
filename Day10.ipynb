# %%
import matplotlib.pyplot as plt
import numpy as np

# create 100 linearly spaced numbers from -10 to 10
x = np.linspace(-10,10,100)
y = 3*x**2 - 2*x + 1 # y = 3x^2 - 2x + 1

# draw the plot
plt.plot(x, y, 'black')

# set the x axis label
plt.xlabel('x')
# set the y axis label
plt.ylabel('y')

# set the plot title
plt.title('y = 3x^2 - 2x + 1')

# show the plot
plt.show()

# %%
# create 100 linearly spaced numbers from -1 to 3
x = np.linspace(-1, 3, 100)
y = 3*x**2 # y = 3x^2

# draw the plot
plt.plot(x, y, 'black')

# set the x axis label
plt.xlabel('x')
# set the y axis label
plt.ylabel('y')

# set the plot title
plt.title('y = 3x^2 - 2x + 1')

# show the plot
plt.show()

# %%
import math
# create 100 linearly spaced numbers from -15 to 15
x = np.linspace(-15, 15, 100)
y = np.cos(x) / (1 + (1/5) * x**2) # y = cosx / 1 + (1/5)x^2

# draw the plot
plt.plot(x, y, 'black')

# set the x axis label
plt.xlabel('x')
# set the y axis label
plt.ylabel('y')

# set the plot title
plt.title('y = cos(x) / (1 + X^2 / 5)')

vline_x = np.zeros(2)
vline_y = np.array([-1, 1.5])

plt.plot(vline_x, vline_y, 'blue')

hline_x = np.array([-15, 15])
hline_y = np.zeros(2)

plt.plot(hline_x, hline_y, 'red')

# show the plot
plt.show()

# %%
names, years, globalSales = np.loadtxt('Datasets/vgsales.csv', skiprows=1, usecols=(1, 3, 10), dtype=str, unpack=True)
game = [['names', 'years', 'globalSales']]
for i in range(len(names)):
    if years[i] != 'N/A':
        print(names[i])
        game.append([names[i], years[i], globalSales[i]])

np.savetxt('Datasets/Game.csv', game, fmt='%s', delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [25], line 1
# ----> 1 names, years, globalSales = np.loadtxt('Datasets/vgsales.csv', skiprows=1, usecols=(1, 3, 10), dtype=str, unpack=True)
#       2 game = [['names', 'years', 'globalSales']]
#       3 for i in range(len(names)):
#
# File h:\Python310\lib\site-packages\numpy\lib\npyio.py:1318, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1315 if isinstance(delimiter, bytes):
#    1316     delimiter = delimiter.decode('latin1')
# -> 1318 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1319             converters=converters, skiplines=skiprows, usecols=usecols,
#    1320             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1321             max_rows=max_rows, quote=quotechar)
#    1323 return arr
# ...
